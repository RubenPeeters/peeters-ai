# %% [markdown]
# ## Quick demo
#
# This is a placeholder notebook to verify the renderer works.

# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['Alice', 'Bob', 'Charlie'],
    'score': [92, 87, 95]
})
df
# Out:
#       name  score
# 0    Alice     92
# 1      Bob     87
# 2  Charlie     95

# %%
print(f'Mean score: {df["score"].mean():.1f}')
# Out:
# Mean score: 91.3
